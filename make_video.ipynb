# %%
from pyMCDS import pyMCDS
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import sys

# %%
def plot_1subs(mcds,n,figure,gs,filenameOut,fileFig,SavePNG):
    cx = mcds.data['discrete_cells']['position_x'];
    cy = mcds.data['discrete_cells']['position_y'];
    
    # First figure
    cellFig   = plt.imread(fileFig)
    ax0 = figure.add_subplot(gs[:,0])
    ax0.axis('off')
    ax0.imshow(cellFig)
    
    # Second figure
    ax1 = figure.add_subplot(gs[0,1])
    subs1 = mcds.get_concentrations( mcds.get_substrate_names()[11] );  # oxygen
    X1,Y1 = mcds.get_2D_mesh();
    CS0 = ax1.contourf(X1,Y1,subs1[:,:,0],cmap='viridis');
    ax1.set_aspect('equal')
    divider = make_axes_locatable(ax1)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = figure.colorbar(CS0,cax=cax)
    ax1.set_title(mcds.get_substrate_names()[0])
    
  
    if (SavePNG):
      figure.savefig(filenameOut)
      #plt.savefig(filenameOut)
    else:
      plt.draw()
      plt.waitforbuttonpress(0) # this will wait for indefinite time
      #plt.pause(0.2)
    plt.clf()

# %%
def plot_2subs(mcds,n,figure,gs,filenameOut,fileFig,SavePNG):
    cx = mcds.data['discrete_cells']['position_x'];
    cy = mcds.data['discrete_cells']['position_y'];
    
    # First figure
    cellFig   = plt.imread(fileFig)
    ax0 = figure.add_subplot(gs[:,0])
    ax0.axis('off')
    ax0.imshow(cellFig)
    
    # Second figure
    ax1 = figure.add_subplot(gs[0,1])
    subs1 = mcds.get_concentrations( mcds.get_substrate_names()[11] );  # oxygen
    X1,Y1 = mcds.get_2D_mesh();
    CS0 = ax1.contourf(X1,Y1,subs1[:,:,0],cmap='viridis');
    ax1.set_aspect('equal')
    divider = make_axes_locatable(ax1)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = figure.colorbar(CS0,cax=cax)
    ax1.set_title(mcds.get_substrate_names()[11])
    
    # Third figure
    ax2 = figure.add_subplot(gs[1,1])
    subs2 = mcds.get_concentrations( mcds.get_substrate_names()[13] );  # LNP
    CS1 = ax2.contourf(X1,Y1,subs2[:,:,0],cmap='viridis');
    ax2.set_aspect('equal')
    divider = make_axes_locatable(ax2)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = figure.colorbar(CS1,cax=cax)
    ax2.set_title(mcds.get_substrate_names()[13])
    

    if (SavePNG):
      figure.savefig(filenameOut)
      #plt.savefig(filenameOut)
    else:
      plt.draw()
      plt.waitforbuttonpress(0) # this will wait for indefinite time
      #plt.pause(0.2)
    plt.clf()

# %%
def Example_1subs(initial_index,last_index,folder,SavePNG,func=plot_1subs):
    figure = plt.figure(figsize=(10,8))
    gs = gridspec.GridSpec(nrows=1, ncols=2)
    for n in range( initial_index,last_index+1 ):
        filenameOut=folder+'/video'+"%08i"%n+'.png'
        filename= "output%08i"%n+'.xml'
        fileFig = folder+'/snapshot'+"%08i"%n+'.jpg'
        mcds=pyMCDS(filename,folder)
        func(mcds,n,figure,gs,filenameOut,fileFig,SavePNG)

# %%
def Example_2subs(initial_index,last_index,folder,SavePNG,func=plot_2subs):
    figure = plt.figure(figsize=(10,8))
    gs = gridspec.GridSpec(nrows=2, ncols=2, width_ratios=[2,1], height_ratios=[1,1])
    for n in range( initial_index,last_index+1 ):
        filenameOut=folder+'/video'+"%08i"%n+'.png'
        filename= "output%08i"%n+'.xml'
        fileFig = folder+'/snapshot'+"%08i"%n+'.jpg'
        mcds=pyMCDS(filename,folder)
        func(mcds,n,figure,gs,filenameOut,fileFig,SavePNG)

# %%
Example_2subs(0, 60, 'output', True)
# Out:
# Reading output/output00000000.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000000_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000000_cells_physicell.mat
# Reading output/output00000001.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000001_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000001_cells_physicell.mat
# Reading output/output00000002.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000002_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000002_cells_physicell.mat
# Reading output/output00000003.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000003_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000003_cells_physicell.mat
# Reading output/output00000004.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000004_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000004_cells_physicell.mat
# Reading output/output00000005.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000005_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000005_cells_physicell.mat
# Reading output/output00000006.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000006_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000006_cells_physicell.mat
# Reading output/output00000007.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000007_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000007_cells_physicell.mat
# Reading output/output00000008.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000008_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000008_cells_physicell.mat
# Reading output/output00000009.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000009_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000009_cells_physicell.mat
# Reading output/output00000010.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000010_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000010_cells_physicell.mat
# Reading output/output00000011.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000011_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000011_cells_physicell.mat
# Reading output/output00000012.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000012_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000012_cells_physicell.mat
# Reading output/output00000013.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000013_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000013_cells_physicell.mat
# Reading output/output00000014.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000014_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000014_cells_physicell.mat
# Reading output/output00000015.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000015_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000015_cells_physicell.mat
# Reading output/output00000016.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000016_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000016_cells_physicell.mat
# Reading output/output00000017.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000017_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000017_cells_physicell.mat
# Reading output/output00000018.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000018_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000018_cells_physicell.mat
# Reading output/output00000019.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000019_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000019_cells_physicell.mat
# Reading output/output00000020.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000020_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000020_cells_physicell.mat
# Reading output/output00000021.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000021_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000021_cells_physicell.mat
# Reading output/output00000022.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000022_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000022_cells_physicell.mat
# Reading output/output00000023.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000023_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000023_cells_physicell.mat
# Reading output/output00000024.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000024_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000024_cells_physicell.mat
# Reading output/output00000025.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000025_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000025_cells_physicell.mat
# Reading output/output00000026.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000026_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000026_cells_physicell.mat
# Reading output/output00000027.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000027_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000027_cells_physicell.mat
# Reading output/output00000028.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000028_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000028_cells_physicell.mat
# Reading output/output00000029.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000029_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000029_cells_physicell.mat
# Reading output/output00000030.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000030_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000030_cells_physicell.mat
# Reading output/output00000031.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000031_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000031_cells_physicell.mat
# Reading output/output00000032.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000032_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000032_cells_physicell.mat
# Reading output/output00000033.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000033_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000033_cells_physicell.mat
# Reading output/output00000034.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000034_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000034_cells_physicell.mat
# Reading output/output00000035.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000035_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000035_cells_physicell.mat
# Reading output/output00000036.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000036_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000036_cells_physicell.mat
# Reading output/output00000037.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000037_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000037_cells_physicell.mat
# Reading output/output00000038.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000038_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000038_cells_physicell.mat
# Reading output/output00000039.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000039_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000039_cells_physicell.mat
# Reading output/output00000040.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000040_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000040_cells_physicell.mat
# Reading output/output00000041.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000041_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000041_cells_physicell.mat
# Reading output/output00000042.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000042_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000042_cells_physicell.mat
# Reading output/output00000043.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000043_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000043_cells_physicell.mat
# Reading output/output00000044.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000044_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000044_cells_physicell.mat
# Reading output/output00000045.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000045_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000045_cells_physicell.mat
# Reading output/output00000046.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000046_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000046_cells_physicell.mat
# Reading output/output00000047.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000047_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000047_cells_physicell.mat
# Reading output/output00000048.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000048_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000048_cells_physicell.mat
# Reading output/output00000049.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000049_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000049_cells_physicell.mat
# Reading output/output00000050.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000050_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000050_cells_physicell.mat
# Reading output/output00000051.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000051_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000051_cells_physicell.mat
# Reading output/output00000052.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000052_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000052_cells_physicell.mat
# Reading output/output00000053.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000053_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000053_cells_physicell.mat
# Reading output/output00000054.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000054_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000054_cells_physicell.mat
# Reading output/output00000055.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000055_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000055_cells_physicell.mat
# Reading output/output00000056.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000056_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000056_cells_physicell.mat
# Reading output/output00000057.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000057_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000057_cells_physicell.mat
# Reading output/output00000058.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000058_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000058_cells_physicell.mat
# Reading output/output00000059.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000059_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000059_cells_physicell.mat
# Reading output/output00000060.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000060_microenvironment0.mat
# Parsing virion data
# Parsing assembled virion data
# Parsing interferon 1 data
# Parsing pro-inflammatory cytokine data
# Parsing chemokine data
# Parsing debris data
# Parsing pro-pyroptosis cytokine data
# Parsing anti-inflammatory cytokine data
# Parsing collagen data
# Parsing Ig data
# Parsing ROS data
# Parsing oxygen data
# Parsing Lipid-nanoparticles data
# Parsing epitope data
# Reading output/output00000060_cells_physicell.mat

# %%
# if __name__ == '__main__':
#     if (len(sys.argv) != 5):
#       print("Please provide 4 args: InitialTime LastTime, SavePNG (bool), and folder")
#       sys.exit(1)
#     initial_index = int(sys.argv[1]);
#     last_index = int(sys.argv[2]);
#     SavePNG = int(sys.argv[3])
#     folder = sys.argv[4]
    
#     mcds=pyMCDS("initial.xml",folder)
#     if (len(mcds.get_substrate_names()) == 1):
#         Example_1subs(initial_index,last_index,folder,SavePNG)
#     if (len(mcds.get_substrate_names()) == 2):
#         Example_2subs(initial_index,last_index,folder,SavePNG)
